# %% [markdown]
# # Spoken language detection

# %% [markdown]
# ## 1.

# %%
import os
import random
import numpy as np
import tensorflow as tf
import librosa
import matplotlib.pyplot as plt
import pandas as pd
import IPython

# %%
PL_LANG_FILE = os.path.join('languages_audio', 'languages_audio_wav', 'pl', 'clips', 'common_voice_pl_20547814.wav')
PL_LANG_FILE
# Out:
# 'languages_audio\\languages_audio_wav\\pl\\clips\\common_voice_pl_20547814.wav'

# %%
file_content = tf.io.read_file(PL_LANG_FILE) # Load encoded wav file
type(file_content)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
wav, sample_rate = tf.audio.decode_wav(file_content, desired_channels=1)

# %%
wav
# Out:
# <tf.Tensor: shape=(240768, 1), dtype=float32, numpy=
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)>

# %%
sample_rate.numpy() # 48 kHz próbkowanie należy zmienic
# Out:
# 48000

# %%
wav = tf.squeeze(wav, axis=-1) # axis=-1 żeby usunąć ostatni wymiar który jest równy 1

# %%
wav
# Out:
# <tf.Tensor: shape=(240768,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>

# %%
wav = librosa.resample(wav.numpy(), orig_sr=sample_rate.numpy(), target_sr=16_000)

# %%
wav = tf.convert_to_tensor(wav, dtype=tf.float32)

# %%
wav_example = wav
wav_example
# Out:
# <tf.Tensor: shape=(80256,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>

# %%
plt.plot(wav)

# %%
IPython.display.Audio(PL_LANG_FILE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 2. Create Dataset

# %%
PL_DIR = os.path.join('languages_audio', 'languages_audio_wav', 'pl', 'clips')
PL_DIR
# Out:
# 'languages_audio\\languages_audio_wav\\pl\\clips'

# %%
# create tensorflow dataset
pl_dataset = tf.data.Dataset.list_files(PL_DIR + '\*.wav')
pl_dataset
# Out:
# <_ShuffleDataset element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %%
pl_dataset.as_numpy_iterator().next()
# Out:
# b'languages_audio\\languages_audio_wav\\pl\\clips\\common_voice_pl_20760857.wav'

# %%
pl_dataset.as_numpy_iterator().next()
# Out:
# b'languages_audio\\languages_audio_wav\\pl\\clips\\common_voice_pl_20628623.wav'

# %%
df = pd.read_csv(os.path.join('languages_audio', 'languages_audio_mp3', 'pl', 'validated.tsv'), sep='\t')
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_24876\1487738958.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join('languages_audio', 'languages_audio_mp3', 'pl', 'validated.tsv'), sep='\t')
#                                                 client_id  \
# 0       02eb087ff2dda32b8dd01a85b4693569a62d56033bf17d...
# 1       039674fdf440f2c9e53ff991cf27230071a2d969342dfd...
# 2       04bb285ec98789c6485651e8e7c5c5897de0462ce196bc...
# 3       068bf7cf01fb28afca5df71713cdbf9f52eb54e3d9eba2...
# 4       0935b1713f2c7947adace84ce007d74bf879f358e5c88d...
# ...                                                   ...
# 131924  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131925  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131926  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131927  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131928  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
#
#                                 path  \
# 0       common_voice_pl_24005493.mp3
# 1       common_voice_pl_20605240.mp3
# 2       common_voice_pl_20605185.mp3
# 3       common_voice_pl_20633386.mp3
# 4       common_voice_pl_24105374.mp3
# ...                              ...
# 131924  common_voice_pl_21659499.mp3
# 131925  common_voice_pl_21659500.mp3
# 131926  common_voice_pl_21659501.mp3
# 131927  common_voice_pl_21659502.mp3
# 131928  common_voice_pl_21659504.mp3
#
#                                               sentence_id  \
# 0       3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...
# 1       52f0b3164e79636bfc13b1cebe4c5665bb215bcf26095e...
# 2       5dd9590867924455c0b3cf4509c805d881a803371b385d...
# 3       cc4d58bd50a90820cd2a7fe8ee771e35af924c61a56621...
# 4       3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...
# ...                                                   ...
# 131924  bf018139e9cb9c21570c757876f2fe4504f6c263d4b68b...
# 131925  e355f502043dd8de0924144ad636a70466b17c01f7f897...
# 131926  3ad3ab45ec4017caf6945d45ef8106d91acbc7c7272a28...
# 131927  0f436de5942a6681274c60800a6996d8fb4f28d4083bf8...
# 131928  a3ca409165353dc3bbaf45ad2ffaf701f35f2d9caabcf4...
#
#                                                  sentence  sentence_domain  \
# 0       Ostatnie słowa wymówił syczącym szeptem i ze z...              NaN
# 1                            Gdzież tu powód do wyrzutów?              NaN
# 2                                               Lubię go.              NaN
# 3                                     — To mi nie pomaga.              NaN
# 4       Ostatnie słowa wymówił syczącym szeptem i ze z...              NaN
# ...                                                   ...              ...
# 131924                   Porwała go i pobiegła do komory.              NaN
# 131925  W drzwiach stał młody krępy górnik o szerokich...              NaN
# 131926  Naprawdę, nie wiedziałem, czy mam się cieszyć,...              NaN
# 131927  Ściany były tak grube, że od sąsiedniego pokoj...              NaN
# 131928  Przy stole, tuż obok, stał człowiek olbrzymieg...              NaN
#
#         up_votes  down_votes       age          gender accents  variant  \
# 0              2           0       NaN             NaN     NaN      NaN
# 1              5           0       NaN             NaN     NaN      NaN
# 2              4           1  thirties  male_masculine     NaN      NaN
# 3              3           1       NaN             NaN     NaN      NaN
# 4              2           0       NaN             NaN     NaN      NaN
# ...          ...         ...       ...             ...     ...      ...
# 131924         2           0  thirties  male_masculine     NaN      NaN
# 131925         2           0  thirties  male_masculine     NaN      NaN
# 131926         2           0  thirties  male_masculine     NaN      NaN
# 131927         2           0  thirties  male_masculine     NaN      NaN
# 131928         2           0  thirties  male_masculine     NaN      NaN
#
#        locale segment
# 0          pl     NaN
# 1          pl     NaN
# 2          pl     NaN
# 3          pl     NaN
# 4          pl     NaN
# ...       ...     ...
# 131924     pl     NaN
# 131925     pl     NaN
# 131926     pl     NaN
# 131927     pl     NaN
# 131928     pl     NaN
#
# [131929 rows x 13 columns]

# %%
df[df['gender'] == 'female_feminine']
# Out:
#                                                 client_id  \
# 24      26b6fc36bff0448de0ed25e2b660056ad036f96005bda9...
# 158     cdd9e3173cd44c3b6695144072c4cf45b7a24a795def30...
# 311     8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636...
# 312     8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636...
# 691     c0af0a34f01c2dd7bf4905cae03217ccc228312b8763ea...
# ...                                                   ...
# 115900  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 115901  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 115902  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 115903  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 115904  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
#
#                                 path  \
# 24      common_voice_pl_23694146.mp3
# 158     common_voice_pl_23579454.mp3
# 311     common_voice_pl_27100225.mp3
# 312     common_voice_pl_27100226.mp3
# 691     common_voice_pl_39597727.mp3
# ...                              ...
# 115900  common_voice_pl_26587805.mp3
# 115901  common_voice_pl_26587807.mp3
# 115902  common_voice_pl_26587809.mp3
# 115903  common_voice_pl_26587813.mp3
# 115904  common_voice_pl_26587815.mp3
#
#                                               sentence_id  \
# 24      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...
# 158     91b75d2edf9c5e09c06eb9191f8f5d3fc97bf0f5a21e37...
# 311     0a17d2f0b55ad6227f51534fcc97664417a192e027980a...
# 312     0a4f7c81091a523aa2ef361c6bf3f56d45f73cfe16483e...
# 691     1da9e571e1ab62bb331baf7fea3b07341b281c0782c5d3...
# ...                                                   ...
# 115900  0958ff79a549e7528519b39cdfca5ae257aa3c90d11be5...
# 115901  0930c019b37b5ba851c5c0f77d84694a59d8fae415e218...
# 115902  093caf621077839d205578607762a57b48773fac57ee84...
# 115903  09a6ab44f2bcd21e58ba65e1d9051f75fd6fb24d0cf384...
# 115904  098eda35deaec91b9fe649fc52b02a7861c908610095e0...
#
#                                                  sentence  sentence_domain  \
# 24      Ostatnie słowa wymówił syczącym szeptem i ze z...              NaN
# 158                                   Mnie to interesuje.              NaN
# 311                                     Brakuje nam czasu              NaN
# 312             Nie ma wątpliwości, że klimat się zmienia              NaN
# 691                       Zmiana wspólnej polityki rolnej              NaN
# ...                                                   ...              ...
# 115900                     uchylanie się od opodatkowania              NaN
# 115901  Uważam również, że debata ta pokazała, jak wie...              NaN
# 115902  I popełnia się ją pod obłudną przykrywką rzeko...              NaN
# 115903  Wydaje się to technicznie możliwe i zostało ju...              NaN
# 115904        Konfrontacja nie przyniesie korzyści nikomu              NaN
#
#         up_votes  down_votes        age           gender accents  variant  \
# 24             2           0   twenties  female_feminine     NaN      NaN
# 158            2           0   twenties  female_feminine     NaN      NaN
# 311            2           0   twenties  female_feminine     NaN      NaN
# 312            2           1   twenties  female_feminine     NaN      NaN
# 691            2           0  seventies  female_feminine     NaN      NaN
# ...          ...         ...        ...              ...     ...      ...
# 115900         2           0   twenties  female_feminine     NaN      NaN
# 115901         2           0   twenties  female_feminine     NaN      NaN
# 115902         2           0   twenties  female_feminine     NaN      NaN
# 115903         2           0   twenties  female_feminine     NaN      NaN
# 115904         2           0   twenties  female_feminine     NaN      NaN
#
#        locale segment
# 24         pl     NaN
# 158        pl     NaN
# 311        pl     NaN
# 312        pl     NaN
# 691        pl     NaN
# ...       ...     ...
# 115900     pl     NaN
# 115901     pl     NaN
# 115902     pl     NaN
# 115903     pl     NaN
# 115904     pl     NaN
#
# [19198 rows x 13 columns]

# %%
df[df['gender'] == 'male_masculine']
# Out:
#                                                 client_id  \
# 2       04bb285ec98789c6485651e8e7c5c5897de0462ce196bc...
# 22      2486bf621942aa6e36ab658e7791aa38563bf908c2485c...
# 37      3358c4d8d0cbcdaed3828313b13ad54cb185fa9bbe17a0...
# 49      46ae7820b8db907ba0951c0db2aca13e4061be363f5b67...
# 52      4d3b0e719909ca39f14a72a0c2af34145bb10442bd1cbc...
# ...                                                   ...
# 131924  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131925  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131926  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131927  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131928  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
#
#                                 path  \
# 2       common_voice_pl_20605185.mp3
# 22      common_voice_pl_23840821.mp3
# 37      common_voice_pl_24085740.mp3
# 49      common_voice_pl_23677778.mp3
# 52      common_voice_pl_20605456.mp3
# ...                              ...
# 131924  common_voice_pl_21659499.mp3
# 131925  common_voice_pl_21659500.mp3
# 131926  common_voice_pl_21659501.mp3
# 131927  common_voice_pl_21659502.mp3
# 131928  common_voice_pl_21659504.mp3
#
#                                               sentence_id  \
# 2       5dd9590867924455c0b3cf4509c805d881a803371b385d...
# 22      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...
# 37      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...
# 49      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...
# 52      3369c1ddb7fb5a2ecf2c155634718817a170f3f8e613ef...
# ...                                                   ...
# 131924  bf018139e9cb9c21570c757876f2fe4504f6c263d4b68b...
# 131925  e355f502043dd8de0924144ad636a70466b17c01f7f897...
# 131926  3ad3ab45ec4017caf6945d45ef8106d91acbc7c7272a28...
# 131927  0f436de5942a6681274c60800a6996d8fb4f28d4083bf8...
# 131928  a3ca409165353dc3bbaf45ad2ffaf701f35f2d9caabcf4...
#
#                                                  sentence  sentence_domain  \
# 2                                               Lubię go.              NaN
# 22      Ostatnie słowa wymówił syczącym szeptem i ze z...              NaN
# 37      Ostatnie słowa wymówił syczącym szeptem i ze z...              NaN
# 49      Ostatnie słowa wymówił syczącym szeptem i ze z...              NaN
# 52       Ona, która go zrozumiała zbyt wąsko: — Ooo, tak.              NaN
# ...                                                   ...              ...
# 131924                   Porwała go i pobiegła do komory.              NaN
# 131925  W drzwiach stał młody krępy górnik o szerokich...              NaN
# 131926  Naprawdę, nie wiedziałem, czy mam się cieszyć,...              NaN
# 131927  Ściany były tak grube, że od sąsiedniego pokoj...              NaN
# 131928  Przy stole, tuż obok, stał człowiek olbrzymieg...              NaN
#
#         up_votes  down_votes       age          gender accents  variant  \
# 2              4           1  thirties  male_masculine     NaN      NaN
# 22             2           0  thirties  male_masculine     NaN      NaN
# 37             2           0  twenties  male_masculine     NaN      NaN
# 49             2           0  twenties  male_masculine     NaN      NaN
# 52             7           0  thirties  male_masculine     NaN      NaN
# ...          ...         ...       ...             ...     ...      ...
# 131924         2           0  thirties  male_masculine     NaN      NaN
# 131925         2           0  thirties  male_masculine     NaN      NaN
# 131926         2           0  thirties  male_masculine     NaN      NaN
# 131927         2           0  thirties  male_masculine     NaN      NaN
# 131928         2           0  thirties  male_masculine     NaN      NaN
#
#        locale segment
# 2          pl     NaN
# 22         pl     NaN
# 37         pl     NaN
# 49         pl     NaN
# 52         pl     NaN
# ...       ...     ...
# 131924     pl     NaN
# 131925     pl     NaN
# 131926     pl     NaN
# 131927     pl     NaN
# 131928     pl     NaN
#
# [79872 rows x 13 columns]

# %%
df.groupby('sentence_id').count()
# Out:
#                                                     client_id  path  sentence  \
# sentence_id
# 000010547254f2aa77c475053f8b6b4c83d434f9bc6b39f...          1     1         1
# 00007f59e910334724585497c5f56c66445dad9a96bad62...          1     1         1
# 0000a42a2e6b7578771b68c98e11c74b5b086a2ac027592...          1     1         1
# 00025f331e89b18ae83e113ca0b1809e73ebb3835b9d7be...          1     1         1
# 00026e9700c3b59e381a73ca0363782efe5016b2375c569...          1     1         1
# ...                                                       ...   ...       ...
# ffecbc28db5bb94420e0417acfd68a3eeaa44c473e0e55e...          3     3         3
# ffef45483b2128ee9ddde50f72279d72bd4122b51298735...          2     2         2
# fff04179750ea84cc1838064e42ab2b595479bec71425ae...          3     3         3
# fff2b775e86188c5c1d3e7756cc8ed986a4525ee6e04cc3...          3     3         3
# 8c4eeac4b0268f6da0712d963ed4c527e004098ca234badee85b77c2453fd704a42e75f0eccd6caa481e5d5d25cb389f0c339690b3718dd2099b9688d1a46b89    11035
# Name: count, Length: 3194, dtype: int64

# %%
df[['sentence_id', 'client_id']].groupby(by='sentence_id').count().sort_values(by='client_id', ascending=False)
# Out:
#                                                     client_id
# sentence_id
# 4c97d8f9de17694342d66084c820814bfa5df996855bfff...         84
# 50ad0cc3186e9995592d55fcd0cd4996cd5952695a1206c...         84
# 4d7eae22f3184a3b7a662defeceec08aa69b68109ede2e5...         84
# f2505897bb27ca76f4b45039caf56ccab070b95f0737bd3...         83
# 60a5f73c90d77d1fe0f2a660c6bbbadc679ece26a0f4646...         83
# ...                                                       ...
# 135d28e4140fed1824b11f9571e100f35c5094f6164fc6c...          1
# 135cfc46346937a25472447586b8aef9e8a40277e1bfece...          1
# 135cb6eddb5ccb7a713f55e8f1f5732c1612b49508c066c...          1
# 135c67ad27d2948d69302bb1e8c0e0ba63ba5b98735bb0e...          1
# 1a533487f781167460a37d2736a02dbdad6ff6befeb88aa...          1
#
# [38536 rows x 1 columns]

# %%
df[['client_id', 'sentence_id']].sort_values(by='client_id', ascending=False)
# Out:
#                                               client_id  \
# 6429  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6431  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6430  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6427  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6428  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# ...                                                 ...
# 2182  000266163565c94f08a466f947dfae7645d83ee9705ee8...
# 2183  000266163565c94f08a466f947dfae7645d83ee9705ee8...
# 2184  000266163565c94f08a466f947dfae7645d83ee9705ee8...
# 2185  000266163565c94f08a466f947dfae7645d83ee9705ee8...
# 2186  000266163565c94f08a466f947dfae7645d83ee9705ee8...
#
#                                             sentence_id
# 6429  c8d122e3a38c2406cfc98e1c92c9b6bfa42360a01ca634...
# 6431  7c049b380c12bde413ab3eb2579079914cb0307db26e8c...
# 6430  b7f580c9ac8f2c2c8e20285a0c16521ab3a979f233277d...
# 6427  ccb6b126fe4d1161924fbc663271fc5fda7308aeee1ceb...
# 6428  c7727ea0625ec2b75629ce52d623e562ff65873c376dc2...
# ...                                                 ...
# 2182  e7f4a9286200d2cf390df58b3258e982c413ec01dc55e3...
# 2183  dfd693f167678a92f8e57fb22361b93d47d2fac99b7f7a...
# 2184  edda6b80d957c47119f35d79a2cd2e0b2cdf7ab9e0d332...
# 2185  f067783bad53e3b3234e06413876aaf070b4896434efd3...
# 2186  ff81e74a80fcc64a23866db4d2ef305812ac055ff295b2...
#
# [131929 rows x 2 columns]

# %%
df[['client_id', 'sentence_id']].sort_values(by='client_id', ascending=False)
# Out:
#                                               client_id  \
# 6429  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6431  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6430  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6427  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6428  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# ...                                                 ...
# 2182  000266163565c94f08a466f947dfae7645d83ee9705ee8...
# 2183  000266163565c94f08a466f947dfae7645d83ee9705ee8...
# 2184  000266163565c94f08a466f947dfae7645d83ee9705ee8...
# 2185  000266163565c94f08a466f947dfae7645d83ee9705ee8...
# 2186  000266163565c94f08a466f947dfae7645d83ee9705ee8...
#
#                                             sentence_id
# 6429  c8d122e3a38c2406cfc98e1c92c9b6bfa42360a01ca634...
# 6431  7c049b380c12bde413ab3eb2579079914cb0307db26e8c...
# 6430  b7f580c9ac8f2c2c8e20285a0c16521ab3a979f233277d...
# 6427  ccb6b126fe4d1161924fbc663271fc5fda7308aeee1ceb...
# 6428  c7727ea0625ec2b75629ce52d623e562ff65873c376dc2...
# ...                                                 ...
# 2182  e7f4a9286200d2cf390df58b3258e982c413ec01dc55e3...
# 2183  dfd693f167678a92f8e57fb22361b93d47d2fac99b7f7a...
# 2184  edda6b80d957c47119f35d79a2cd2e0b2cdf7ab9e0d332...
# 2185  f067783bad53e3b3234e06413876aaf070b4896434efd3...
# 2186  ff81e74a80fcc64a23866db4d2ef305812ac055ff295b2...
#
# [131929 rows x 2 columns]

# %%
df[df['client_id'] == 'ffffc00a5ed69f08a486837064ec2caeff21fe06264c3dd733f633fb6c2ae9aeb561a5a6f43e000554d4b3cc171644ba4ce971177af1cb54f9bd8cc153e71a5c']
# Out:
#                                               client_id  \
# 6427  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6428  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6429  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6430  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
# 6431  ffffc00a5ed69f08a486837064ec2caeff21fe06264c3d...
#
#                               path  \
# 6427  common_voice_pl_20642313.mp3
# 6428  common_voice_pl_20642315.mp3
# 6429  common_voice_pl_20642317.mp3
# 6430  common_voice_pl_20642319.mp3
# 6431  common_voice_pl_20642321.mp3
#
#                                             sentence_id  \
# 6427  ccb6b126fe4d1161924fbc663271fc5fda7308aeee1ceb...
# 6428  c7727ea0625ec2b75629ce52d623e562ff65873c376dc2...
# 6429  c8d122e3a38c2406cfc98e1c92c9b6bfa42360a01ca634...
# 6430  b7f580c9ac8f2c2c8e20285a0c16521ab3a979f233277d...
# 6431  7c049b380c12bde413ab3eb2579079914cb0307db26e8c...
#
#                                                sentence  sentence_domain  \
# 6427  Nie znam takiego, a jednak widziałem go nagieg...              NaN
# 6428  Apollo, chcąc objąć Daphne — objął krzew laurowy.              NaN
# 6429                            I mało w tym było pozy.              NaN
# 6430       Urządzono w wielu miastach kluby dla dzieci.              NaN
# 6431  Pewnego razu ona powiedziała do niego: — Twoje...              NaN
#
#       up_votes  down_votes  age gender accents  variant locale segment
# 6427         2           0  NaN    NaN     NaN      NaN     pl     NaN
# 6428         3           0  NaN    NaN     NaN      NaN     pl     NaN
# 6429         2           0  NaN    NaN     NaN      NaN     pl     NaN
# 6430         2           0  NaN    NaN     NaN      NaN     pl     NaN
# 6431         2           0  NaN    NaN     NaN      NaN     pl     NaN

# %%
# # sprawdzenie czy client_id oraz sequence_id się nie duplikują (czy jeden klient ma rózne sekwencej)
# 
# for client_id in df['client_id'].unique():
#     sentence_count = df['sentence_id'][df['client_id']  == client_id].count()
#     client_id_count = df['client_id'][df['client_id']  == client_id].value_counts().iloc[0]
#     if sentence_count != client_id_count:
#         print(True)

# %%
df['sentence_id'][df['client_id']  == 'ffffc00a5ed69f08a486837064ec2caeff21fe06264c3dd733f633fb6c2ae9aeb561a5a6f43e000554d4b3cc171644ba4ce971177af1cb54f9bd8cc153e71a5c'].count()
# Out:
# 5

# %%
df['client_id'][df['client_id']  == 'ffffc00a5ed69f08a486837064ec2caeff21fe06264c3dd733f633fb6c2ae9aeb561a5a6f43e000554d4b3cc171644ba4ce971177af1cb54f9bd8cc153e71a5c'].value_counts()
# Out:
# client_id
# ffffc00a5ed69f08a486837064ec2caeff21fe06264c3dd733f633fb6c2ae9aeb561a5a6f43e000554d4b3cc171644ba4ce971177af1cb54f9bd8cc153e71a5c    5
# Name: count, dtype: int64

# %%
# TODO: WZiąć plik validated.tsv nastepnie podzielić go na mężczyzn i kobiety (dwa osobne dataset) [DONE]. następnie wrzucać do każdego ze zbiorów (najpiew testwoy, walidacyjny, treningowy) client_id od najmniejszej liczby wystąpień w obydwu  dopasować czas trwania każdej próbki (najpierw obcinać od środka, potem dopełniać zerami), zmienić na spektogram i dopiero wtedy dodać (koniec funkcji). druga funkcja będzie jako augumentowanie losowych danych (losowo wybiera funkcję która coś zrobi z danymi) jeżeli moje zbiory kobiet i mężczyzn nie będą spełniały wymaganej ilości próbek którą się poda. Na wyjściu ma być tensor z próbkami spektogramu. To zrobić finalnie dla każdego folderu (języka). Wtedy dopiero dodać label w formie one hot encoding

# %% [markdown]
# ## Load data:

# %%
df = pd.read_csv(os.path.join('languages_audio', 'languages_audio_mp3', 'pl', 'validated.tsv'), sep='\t', usecols=['client_id', 'path', 'sentence_id', 'gender', 'locale'])

# %% [markdown]
# ## Change mp3 to wav name

# %%
df = df.apply(lambda path: path.str.replace('.mp3', '.wav'))

# %% [markdown]
# ## Split to woman and man sets

# %%
df
# Out:
#                                                 client_id  \
# 0       02eb087ff2dda32b8dd01a85b4693569a62d56033bf17d...
# 1       039674fdf440f2c9e53ff991cf27230071a2d969342dfd...
# 2       04bb285ec98789c6485651e8e7c5c5897de0462ce196bc...
# 3       068bf7cf01fb28afca5df71713cdbf9f52eb54e3d9eba2...
# 4       0935b1713f2c7947adace84ce007d74bf879f358e5c88d...
# ...                                                   ...
# 131924  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131925  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131926  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131927  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131928  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
#
#                                 path  \
# 0       common_voice_pl_24005493.wav
# 1       common_voice_pl_20605240.wav
# 2       common_voice_pl_20605185.wav
# 3       common_voice_pl_20633386.wav
# 4       common_voice_pl_24105374.wav
# ...                              ...
# 131924  common_voice_pl_21659499.wav
# 131925  common_voice_pl_21659500.wav
# 131926  common_voice_pl_21659501.wav
# 131927  common_voice_pl_21659502.wav
# 131928  common_voice_pl_21659504.wav
#
#                                               sentence_id          gender  \
# 0       3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...             NaN
# 1       52f0b3164e79636bfc13b1cebe4c5665bb215bcf26095e...             NaN
# 2       5dd9590867924455c0b3cf4509c805d881a803371b385d...  male_masculine
# 3       cc4d58bd50a90820cd2a7fe8ee771e35af924c61a56621...             NaN
# 4       3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...             NaN
# ...                                                   ...             ...
# 131924  bf018139e9cb9c21570c757876f2fe4504f6c263d4b68b...  male_masculine
# 131925  e355f502043dd8de0924144ad636a70466b17c01f7f897...  male_masculine
# 131926  3ad3ab45ec4017caf6945d45ef8106d91acbc7c7272a28...  male_masculine
# 131927  0f436de5942a6681274c60800a6996d8fb4f28d4083bf8...  male_masculine
# 131928  a3ca409165353dc3bbaf45ad2ffaf701f35f2d9caabcf4...  male_masculine
#
#        locale
# 0          pl
# 1          pl
# 2          pl
# 3          pl
# 4          pl
# ...       ...
# 131924     pl
# 131925     pl
# 131926     pl
# 131927     pl
# 131928     pl
#
# [131929 rows x 5 columns]

# %%
woman_filter = df['gender'] == 'female_feminine'
man_filter = df['gender'] == 'male_masculine'

# %%
df_women = df[woman_filter]
df_women
# Out:
#                                                 client_id  \
# 24      26b6fc36bff0448de0ed25e2b660056ad036f96005bda9...
# 158     cdd9e3173cd44c3b6695144072c4cf45b7a24a795def30...
# 311     8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636...
# 312     8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636...
# 691     c0af0a34f01c2dd7bf4905cae03217ccc228312b8763ea...
# ...                                                   ...
# 115900  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 115901  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 115902  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 115903  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 115904  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
#
#                                 path  \
# 24      common_voice_pl_23694146.wav
# 158     common_voice_pl_23579454.wav
# 311     common_voice_pl_27100225.wav
# 312     common_voice_pl_27100226.wav
# 691     common_voice_pl_39597727.wav
# ...                              ...
# 115900  common_voice_pl_26587805.wav
# 115901  common_voice_pl_26587807.wav
# 115902  common_voice_pl_26587809.wav
# 115903  common_voice_pl_26587813.wav
# 115904  common_voice_pl_26587815.wav
#
#                                               sentence_id           gender  \
# 24      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...  female_feminine
# 158     91b75d2edf9c5e09c06eb9191f8f5d3fc97bf0f5a21e37...  female_feminine
# 311     0a17d2f0b55ad6227f51534fcc97664417a192e027980a...  female_feminine
# 312     0a4f7c81091a523aa2ef361c6bf3f56d45f73cfe16483e...  female_feminine
# 691     1da9e571e1ab62bb331baf7fea3b07341b281c0782c5d3...  female_feminine
# ...                                                   ...              ...
# 115900  0958ff79a549e7528519b39cdfca5ae257aa3c90d11be5...  female_feminine
# 115901  0930c019b37b5ba851c5c0f77d84694a59d8fae415e218...  female_feminine
# 115902  093caf621077839d205578607762a57b48773fac57ee84...  female_feminine
# 115903  09a6ab44f2bcd21e58ba65e1d9051f75fd6fb24d0cf384...  female_feminine
# 115904  098eda35deaec91b9fe649fc52b02a7861c908610095e0...  female_feminine
#
#        locale
# 24         pl
# 158        pl
# 311        pl
# 312        pl
# 691        pl
# ...       ...
# 115900     pl
# 115901     pl
# 115902     pl
# 115903     pl
# 115904     pl
#
# [19198 rows x 5 columns]

# %%
df_men = df[man_filter]
df_men
# Out:
#                                                 client_id  \
# 2       04bb285ec98789c6485651e8e7c5c5897de0462ce196bc...
# 22      2486bf621942aa6e36ab658e7791aa38563bf908c2485c...
# 37      3358c4d8d0cbcdaed3828313b13ad54cb185fa9bbe17a0...
# 49      46ae7820b8db907ba0951c0db2aca13e4061be363f5b67...
# 52      4d3b0e719909ca39f14a72a0c2af34145bb10442bd1cbc...
# ...                                                   ...
# 131924  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131925  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131926  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131927  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
# 131928  8c4eeac4b0268f6da0712d963ed4c527e004098ca234ba...
#
#                                 path  \
# 2       common_voice_pl_20605185.wav
# 22      common_voice_pl_23840821.wav
# 37      common_voice_pl_24085740.wav
# 49      common_voice_pl_23677778.wav
# 52      common_voice_pl_20605456.wav
# ...                              ...
# 131924  common_voice_pl_21659499.wav
# 131925  common_voice_pl_21659500.wav
# 131926  common_voice_pl_21659501.wav
# 131927  common_voice_pl_21659502.wav
# 131928  common_voice_pl_21659504.wav
#
#                                               sentence_id          gender  \
# 2       5dd9590867924455c0b3cf4509c805d881a803371b385d...  male_masculine
# 22      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...  male_masculine
# 37      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...  male_masculine
# 49      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...  male_masculine
# 52      3369c1ddb7fb5a2ecf2c155634718817a170f3f8e613ef...  male_masculine
# ...                                                   ...             ...
# 131924  bf018139e9cb9c21570c757876f2fe4504f6c263d4b68b...  male_masculine
# 131925  e355f502043dd8de0924144ad636a70466b17c01f7f897...  male_masculine
# 131926  3ad3ab45ec4017caf6945d45ef8106d91acbc7c7272a28...  male_masculine
# 131927  0f436de5942a6681274c60800a6996d8fb4f28d4083bf8...  male_masculine
# 131928  a3ca409165353dc3bbaf45ad2ffaf701f35f2d9caabcf4...  male_masculine
#
#        locale
# 2          pl
# 22         pl
# 37         pl
# 49         pl
# 52         pl
# ...       ...
# 131924     pl
# 131925     pl
# 131926     pl
# 131927     pl
# 131928     pl
#
# [79872 rows x 5 columns]

# %% [markdown]
# ## Set number of probes in my set and split it to train, validate and test

# %%
SET_SIZE = 1_000
MAX_NUMBER_OF_CLIENT_ID = 3000
MIN_CLIP_DURATION = 4000 #  clip time in [ms]

TRAIN_SIZE = int(SET_SIZE * 0.6)
VAL_SIZE = int((SET_SIZE - TRAIN_SIZE) // 2)
TEST_SIZE = SET_SIZE - TRAIN_SIZE - VAL_SIZE

print(f'Train size: {TRAIN_SIZE}')
print(f'Validation size: {VAL_SIZE}')
print(f'Test size: {TEST_SIZE}')
print(f'Sum of sizes: {TRAIN_SIZE + VAL_SIZE + TEST_SIZE} is equal to SET_SIZE {TRAIN_SIZE + VAL_SIZE + TEST_SIZE == SET_SIZE}')
# Out:
# Train size: 600
# Validation size: 200
# Test size: 200
# Sum of sizes: 1000 is equal to SET_SIZE True

# %%
# Select probes with min that time 
df_clips_duration = pd.read_csv(os.path.join('languages_audio', 'languages_audio_mp3', 'pl', 'clip_durations.tsv'), sep='\t')
df_clips_duration['clip'] = df_clips_duration['clip'].apply(lambda clip: clip.replace('.mp3', '.wav'))
df_women = df_women.merge(df_clips_duration, left_on='path', right_on='clip')
df_women
# Out:
#                                                client_id  \
# 0      26b6fc36bff0448de0ed25e2b660056ad036f96005bda9...
# 1      cdd9e3173cd44c3b6695144072c4cf45b7a24a795def30...
# 2      8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636...
# 3      8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636...
# 4      c0af0a34f01c2dd7bf4905cae03217ccc228312b8763ea...
# ...                                                  ...
# 19193  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19194  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19195  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19196  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19197  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
#
#                                path  \
# 0      common_voice_pl_23694146.wav
# 1      common_voice_pl_23579454.wav
# 2      common_voice_pl_27100225.wav
# 3      common_voice_pl_27100226.wav
# 4      common_voice_pl_39597727.wav
# ...                             ...
# 19193  common_voice_pl_26587805.wav
# 19194  common_voice_pl_26587807.wav
# 19195  common_voice_pl_26587809.wav
# 19196  common_voice_pl_26587813.wav
# 19197  common_voice_pl_26587815.wav
#
#                                              sentence_id           gender  \
# 0      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...  female_feminine
# 1      91b75d2edf9c5e09c06eb9191f8f5d3fc97bf0f5a21e37...  female_feminine
# 2      0a17d2f0b55ad6227f51534fcc97664417a192e027980a...  female_feminine
# 3      0a4f7c81091a523aa2ef361c6bf3f56d45f73cfe16483e...  female_feminine
# 4      1da9e571e1ab62bb331baf7fea3b07341b281c0782c5d3...  female_feminine
# ...                                                  ...              ...
# 19193  0958ff79a549e7528519b39cdfca5ae257aa3c90d11be5...  female_feminine
# 19194  0930c019b37b5ba851c5c0f77d84694a59d8fae415e218...  female_feminine
# 19195  093caf621077839d205578607762a57b48773fac57ee84...  female_feminine
# 19196  09a6ab44f2bcd21e58ba65e1d9051f75fd6fb24d0cf384...  female_feminine
# 19197  098eda35deaec91b9fe649fc52b02a7861c908610095e0...  female_feminine
#
#       locale                          clip  duration[ms]
# 0         pl  common_voice_pl_23694146.wav          8424
# 1         pl  common_voice_pl_23579454.wav          3384
# 2         pl  common_voice_pl_27100225.wav          3276
# 3         pl  common_voice_pl_27100226.wav          6156
# 4         pl  common_voice_pl_39597727.wav          3528
# ...      ...                           ...           ...
# 19193     pl  common_voice_pl_26587805.wav          3168
# 19194     pl  common_voice_pl_26587807.wav          9288
# 19195     pl  common_voice_pl_26587809.wav          5256
# 19196     pl  common_voice_pl_26587813.wav          5148
# 19197     pl  common_voice_pl_26587815.wav          3456
#
# [19198 rows x 7 columns]

# %%
# 
# for i in range(len(df_clips_duration)):
#     print(i)
#     row_in_df = df_men[df_men['path']== df_clips_duration.iloc[i]['clip']] 
#     if (df_clips_duration.iloc[i]['duration[ms]'] >= MIN_CLIP_DURATION) and (len(row_in_df) >= 0):
#         rows_over_min_dur_time = pd.concat([rows_over_min_dur_time, row_in_df])
#     else:
#         rows_under_min_dur_time = pd.concat([rows_under_min_dur_time, row_in_df])
# 
# 

rows_over_min_dur_time = df_women[df_women['duration[ms]'] >= MIN_CLIP_DURATION]
rows_under_min_dur_time = df_women[df_women['duration[ms]'] < MIN_CLIP_DURATION]
rows_over_min_dur_time
# Out:
#                                                client_id  \
# 0      26b6fc36bff0448de0ed25e2b660056ad036f96005bda9...
# 3      8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636...
# 5      c0af0a34f01c2dd7bf4905cae03217ccc228312b8763ea...
# 6      c0af0a34f01c2dd7bf4905cae03217ccc228312b8763ea...
# 7      43fd246b33f31507604fc44e1b68343f42430b81c47402...
# ...                                                  ...
# 19189  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19191  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19194  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19195  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19196  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
#
#                                path  \
# 0      common_voice_pl_23694146.wav
# 3      common_voice_pl_27100226.wav
# 5      common_voice_pl_39597729.wav
# 6      common_voice_pl_39597731.wav
# 7      common_voice_pl_23651459.wav
# ...                             ...
# 19189  common_voice_pl_26360071.wav
# 19191  common_voice_pl_26360073.wav
# 19194  common_voice_pl_26587807.wav
# 19195  common_voice_pl_26587809.wav
# 19196  common_voice_pl_26587813.wav
#
#                                              sentence_id           gender  \
# 0      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...  female_feminine
# 3      0a4f7c81091a523aa2ef361c6bf3f56d45f73cfe16483e...  female_feminine
# 5      1d10f0a9a003d3acae7067997f9a1788b423d00f9e116f...  female_feminine
# 6      1d5515bdf51f14b4948f2448dbafd49078254408f96842...  female_feminine
# 7      1d58854998bcb24148577a12d88b7c1d9111e90590f42c...  female_feminine
# ...                                                  ...              ...
# 19192     pl  common_voice_pl_26360074.wav          2268
# 19193     pl  common_voice_pl_26587805.wav          3168
# 19197     pl  common_voice_pl_26587815.wav          3456
#
# [9134 rows x 7 columns]

# %%
if len(rows_over_min_dur_time) >= SET_SIZE:
    df_women = rows_over_min_dur_time
else:
    df_women = pd.concat([rows_over_min_dur_time, rows_under_min_dur_time], ignore_index=True)[:SET_SIZE]

df_women
# Out:
#                                                client_id  \
# 0      26b6fc36bff0448de0ed25e2b660056ad036f96005bda9...
# 3      8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636...
# 5      c0af0a34f01c2dd7bf4905cae03217ccc228312b8763ea...
# 6      c0af0a34f01c2dd7bf4905cae03217ccc228312b8763ea...
# 7      43fd246b33f31507604fc44e1b68343f42430b81c47402...
# ...                                                  ...
# 19189  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19191  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19194  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19195  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
# 19196  d9c913215277238571f601e0e7963bb1dc371ec6e353b5...
#
#                                path  \
# 0      common_voice_pl_23694146.wav
# 3      common_voice_pl_27100226.wav
# 5      common_voice_pl_39597729.wav
# 6      common_voice_pl_39597731.wav
# 7      common_voice_pl_23651459.wav
# ...                             ...
# 19189  common_voice_pl_26360071.wav
# 19191  common_voice_pl_26360073.wav
# 19194  common_voice_pl_26587807.wav
# 19195  common_voice_pl_26587809.wav
# 19196  common_voice_pl_26587813.wav
#
#                                              sentence_id           gender  \
# 0      3538b2608e1451fa8cb7aea203d1515df86d6a4f933bde...  female_feminine
# 3      0a4f7c81091a523aa2ef361c6bf3f56d45f73cfe16483e...  female_feminine
# 5      1d10f0a9a003d3acae7067997f9a1788b423d00f9e116f...  female_feminine
# 6      1d5515bdf51f14b4948f2448dbafd49078254408f96842...  female_feminine
# 7      1d58854998bcb24148577a12d88b7c1d9111e90590f42c...  female_feminine
# ...                                                  ...              ...
# 19189  08b1478ab4a6d2173120b97ce2f59048b2564e4e823b22...  female_feminine
# 19191  07cbd8a78863f35708e615753c2552267004159b349677...  female_feminine
# 19194  0930c019b37b5ba851c5c0f77d84694a59d8fae415e218...  female_feminine
# 19195  093caf621077839d205578607762a57b48773fac57ee84...  female_feminine
# 19196  09a6ab44f2bcd21e58ba65e1d9051f75fd6fb24d0cf384...  female_feminine
#
#       locale                          clip  duration[ms]
# 0         pl  common_voice_pl_23694146.wav          8424
# 3         pl  common_voice_pl_27100226.wav          6156
# 5         pl  common_voice_pl_39597729.wav          6408
# 6         pl  common_voice_pl_39597731.wav          7560
# 7         pl  common_voice_pl_23651459.wav          5736
# ...      ...                           ...           ...
# 19189     pl  common_voice_pl_26360071.wav          5940
# 19191     pl  common_voice_pl_26360073.wav          5076
# 19194     pl  common_voice_pl_26587807.wav          9288
# 19195     pl  common_voice_pl_26587809.wav          5256
# 19196     pl  common_voice_pl_26587813.wav          5148
#
# [10064 rows x 7 columns]

# %%
df_train = pd.DataFrame()
df_val = pd.DataFrame()
df_test = pd.DataFrame()

# %%
df_counted_id = df_women['client_id'].value_counts(ascending=True)
df_counted_id
# Out:
# client_id
# 26b6fc36bff0448de0ed25e2b660056ad036f96005bda9816495bf938d5f98c393304f376aa4b8d27eb457dbd3e9e41e5f6f180b0ce1ed3fcc4cff52b6d3d16a       1
# 8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636126e1b144b9b1f66492ea11cdb468da92c6decc5b490817742e915e72df0c0844b806f0f0b253009af       1
# c0af0a34f01c2dd7bf4905cae03217ccc228312b8763ea6b9a826c2196e42fe6e102b384aa25a0258e42de1391fbce11c6ef73b5f3193bfcff2cb78db0e1cc49       2
# ac46562bb1e672921a9fc4e7bf29ed66a17a3bb354dfd1865fdd60ee0f9060a9d91418d725f7b52e906be569d2e1a42ddf7aae4511cd7c2f4daefb06babe49b0       2
# 059d5f2e926e0de282d9aad9df1d47ae2ff3afb4fb60f3c25edc2b1655635fd989356b6b0fcb2e1ceb11ea908f89a0d989005bbbb734c4e0e11de568dd5f1aeb       2
#                                                                                                                                     ...
# 72a8725537f15ecfbd2aca0c342ee4ac0367ad23595ccd3d7efadb015af1af5e0614adb92ad6bf009711df662453a870c31467ca0ec71005a00aa82dc5e02a40     592
# 6caf100b986fe0662226191fd70cd57b4c5f5f576fce30935a6eba6e0e801083bb275313d82303e75f14ccbddb9748f9f5c622dc8b013617db25bf4e91628253     930
# 2c818dfafa7197d291cac63a8b8f41377c82ebf481d2a81244a0329a579d58a91d57d2de0938abb8b4dda68239b41046591191bf1400b012becb05434b37bb36    1367
# c666546baeecd06b8170a87af5fc862f8ffc037414959aa738f0fa9d9783efa38f5f9dd8fa9ab7881f408934b9de737cb7278d99e40de481494c3332313eb623    1738
# d9c913215277238571f601e0e7963bb1dc371ec6e353b5b0704b532efb9f10b3ee1c93c47ccf71c0192aefbd6335d928da20b3e300a804f6332d9663cc9571da    2278
# Name: count, Length: 81, dtype: int64

# %%
# clients_form_origin_df = df_women[df_women['client_id'] == df_counted_id.index[200]]
# clients_form_origin_df1 = df_women[df_women['client_id'] == df_counted_id.index[201]]
# clients_form_origin_df1['client_id'].iloc[0]

# %%
# df_test = pd.concat([df_test, clients_form_origin_df], ignore_index=True)
# df_test = pd.concat([df_test, clients_form_origin_df1], ignore_index=True)
# df_test

# %%
for i in range(len(df_counted_id)):
    print(df_counted_id.index[i], df_counted_id.iloc[i])
    rows_form_origin_df = df_women[df_women['client_id'] == df_counted_id.index[i]][:MAX_NUMBER_OF_CLIENT_ID]
    if len(rows_form_origin_df) <= (TEST_SIZE - len(df_test)) and rows_form_origin_df['client_id'].iloc[0] not in df_test:
        df_test = pd.concat([df_test, rows_form_origin_df], ignore_index=True)
        continue
    if len(rows_form_origin_df) <= (VAL_SIZE - len(df_val)):
        df_val = pd.concat([df_val, rows_form_origin_df], ignore_index=True)
        continue
    if len(rows_form_origin_df) <= (TRAIN_SIZE - len(df_train)):
        df_train = pd.concat([df_train, rows_form_origin_df], ignore_index=True)
        continue
# Out:
# 26b6fc36bff0448de0ed25e2b660056ad036f96005bda9816495bf938d5f98c393304f376aa4b8d27eb457dbd3e9e41e5f6f180b0ce1ed3fcc4cff52b6d3d16a 1
# 8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636126e1b144b9b1f66492ea11cdb468da92c6decc5b490817742e915e72df0c0844b806f0f0b253009af 1
# c0af0a34f01c2dd7bf4905cae03217ccc228312b8763
# d8657972cd45d36adf19a2a1ef2d0b73f6d4975f1707886ee6c38dd9959f9aef9f8c70fd9d916a33b0999e183945ed16e7efc904b95ae1a11f367b47d59cb4d6     3
# f9fbde6ffa153d920e85e9ab8ab8a7bf7f14fa1c51acabe00452c70d704110971a08cd8be69e4123b09457a22e3e7766a330ab3f3ddfd632e433893fe8fe2900     3
# 59c6424830a72e93a871413677e3ff9a63793650b5ee935e746103b967860c8e7adeebe7be7685106d5d1c326e5ab0993ceea7a8550941ca9dc0ad7a5d549441     3
# c0af0a34f01c2dd7bf4905cae03217ccc228312b8763ea6b9a826c2196e42fe6e102b384aa25a0258e42de1391fbce11c6ef73b5f3193bfcff2cb78db0e1cc49     2
# 059d5f2e926e0de282d9aad9df1d47ae2ff3afb4fb60f3c25edc2b1655635fd989356b6b0fcb2e1ceb11ea908f89a0d989005bbbb734c4e0e11de568dd5f1aeb     2
# ac46562bb1e672921a9fc4e7bf29ed66a17a3bb354dfd1865fdd60ee0f9060a9d91418d725f7b52e906be569d2e1a42ddf7aae4511cd7c2f4daefb06babe49b0     2
# 8b6747c24dfbc22ebb50658b742d9e4e6dd59f2d412636126e1b144b9b1f66492ea11cdb468da92c6decc5b490817742e915e72df0c0844b806f0f0b253009af     1
# 26b6fc36bff0448de0ed25e2b660056ad036f96005bda9816495bf938d5f98c393304f376aa4b8d27eb457dbd3e9e41e5f6f180b0ce1ed3fcc4cff52b6d3d16a     1
# Name: count, dtype: int64

# %% [markdown]
# ## Audio Preprocessing

# %%
df_test_filenames = df_test['path']
df_val_filenames = df_val['path']
df_train_filenames = df_train['path']
df_test_filenames
# Out:
# 0      common_voice_pl_23694146.wav
# 1      common_voice_pl_27100226.wav
# 2      common_voice_pl_39597729.wav
# 3      common_voice_pl_39597731.wav
# 4      common_voice_pl_20624939.wav
#                    ...
# 195    common_voice_pl_21077884.wav
# 196    common_voice_pl_21077979.wav
# 197    common_voice_pl_21078013.wav
# 198    common_voice_pl_21078017.wav
# 199    common_voice_pl_21078019.wav
# Name: path, Length: 200, dtype: object

# %%
df_val_filenames
# Out:
# 0      common_voice_pl_21641808.wav
# 1      common_voice_pl_21641809.wav
# 2      common_voice_pl_21641833.wav
# 3      common_voice_pl_21641835.wav
# 4      common_voice_pl_21641877.wav
#                    ...
# 190    common_voice_pl_20794647.wav
# 191    common_voice_pl_20794650.wav
# 192    common_voice_pl_20794652.wav
# 193    common_voice_pl_20794654.wav
# 194    common_voice_pl_20794656.wav
# Name: path, Length: 195, dtype: object

# %%
PL_DIR = os.path.join('languages_audio', 'languages_audio_wav', 'pl', 'clips')
PL_DIR
# Out:
# 'languages_audio\\languages_audio_wav\\pl\\clips'

# %%
# TEST
df_train_filenames = df_train_filenames.apply(lambda fn: os.path.join(PL_DIR, fn))
df_val_filenames = df_val_filenames.apply(lambda fn: os.path.join(PL_DIR, fn))
df_test_filenames = df_test_filenames.apply(lambda fn: os.path.join(PL_DIR, fn))
df_val_filenames
# Out:
# 0      languages_audio\languages_audio_wav\pl\clips\c...
# 1      languages_audio\languages_audio_wav\pl\clips\c...
# 2      languages_audio\languages_audio_wav\pl\clips\c...
# 3      languages_audio\languages_audio_wav\pl\clips\c...
# 4      languages_audio\languages_audio_wav\pl\clips\c...
#                              ...
# 190    languages_audio\languages_audio_wav\pl\clips\c...
# 191    languages_audio\languages_audio_wav\pl\clips\c...
# 192    languages_audio\languages_audio_wav\pl\clips\c...
# 193    languages_audio\languages_audio_wav\pl\clips\c...
# 194    languages_audio\languages_audio_wav\pl\clips\c...
# Name: path, Length: 195, dtype: object

# %%
# STARE
# pl_dataset_train = tf.data.Dataset.from_tensor_slices(df_train_filenames.apply(lambda fn: os.path.join(PL_DIR, fn)))
# pl_dataset_val = tf.data.Dataset.from_tensor_slices(df_val_filenames.apply(lambda fn: os.path.join(PL_DIR, fn)))
# pl_dataset_test = tf.data.Dataset.from_tensor_slices(df_test_filenames.apply(lambda fn: os.path.join(PL_DIR, fn)))

# %%
sample_rate = 48_000

def add_zeros(wav, sample_rate):
    time_probes = wav.shape[0]
    missing_probes_one_side = int((MIN_CLIP_DURATION/1000* sample_rate - time_probes)//2)
    padded_tensor = tf.pad(wav.numpy(), [[missing_probes_one_side, missing_probes_one_side]])
    return tf.convert_to_tensor(padded_tensor, dtype=tf.float32)

def cut_wav(wav, sample_rate):
    time_probes = wav.shape[0]
    # clip_dur_in_sec = time_probes / sample_rate
    overlap = int((time_probes - (MIN_CLIP_DURATION/1000) * sample_rate)/2) 
    cut_clip = wav[overlap:(time_probes - overlap)]
    return tf.convert_to_tensor(cut_clip, dtype=tf.float32)

def load_wav_16k_mono_and_resample(filename, fin_sam_rate=16_000):
    file_content = tf.io.read_file(filename)
    wav, sample_rate = tf.audio.decode_wav(file_content, desired_channels=1)
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int32)
    # wav = librosa.resample(wav.numpy(), orig_sr=sample_rate.numpy(), target_sr=fin_sam_rate)
    # return wav
    # return tf.convert_to_tensor(wav, dtype=tf.float32), sample_rate.numpy()
    return tf.convert_to_tensor(wav, dtype=tf.float32)

def load_and_align_probes(file_path):
    wav = load_wav_16k_mono_and_resample(file_path)
    expected_probes = int((MIN_CLIP_DURATION/1000) * sample_rate)
    print(expected_probes)
    current_probes = wav.shape[0]
    print(current_probes)
    if expected_probes > current_probes:
        print("Add zeros")
        return add_zeros(wav, sample_rate)
    elif expected_probes < current_probes:
        print("Cut wav")
        return cut_wav(wav, sample_rate)
    return tf.convert_to_tensor(wav, dtype=tf.float32)

# %%
train_align_tensors = df_train_filenames.apply(lambda filename: load_and_align_probes(filename))
val_align_tensors = df_test_filenames.apply(lambda filename: load_and_align_probes(filename))
test_align_tensors = df_val_filenames.apply(lambda filename: load_and_align_probes(filename))


test_align_tensors
type(test_align_tensors)
# df_train_filenames[:5].apply(lambda filename: load_and_align_probes(filename))
# Out:
# 192000
# 298368
# Cut wav
# 192000
# 387072
# Cut wav
# 192000
# 263808
# Cut wav
# 192000
# 237312
# Cut wav
# 192000
# 208512
# Cut wav
# 192000
# 300672
# Cut wav
# 192000
# 398592
# Cut wav
# 192000
# 249984
# Cut wav
# 192000
# 337536
# Cut wav
# 192000
# 232704
# Cut wav
# 192000
# 452736
# Cut wav
# 192000
# 417024
# Cut wav
# 192000
# 213120
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 286848
# Cut wav
# 192000
# 405504
# Cut wav
# 192000
# 277632
# Cut wav
# 192000
# 329472
# Cut wav
# 192000
# 342144
# Cut wav
# 192000
# 247680
# Cut wav
# 192000
# 229248
# Cut wav
# 192000
# 245376
# Cut wav
# 192000
# 218880
# Cut wav
# 192000
# 435456
# Cut wav
# 192000
# 288000
# Cut wav
# 192000
# 402048
# Cut wav
# 192000
# 269568
# Cut wav
# 192000
# 220032
# Cut wav
# 192000
# 263808
# Cut wav
# 192000
# 220032
# Cut wav
# 192000
# 235008
# Cut wav
# 192000
# 298368
# Cut wav
# 192000
# 332928
# Cut wav
# 192000
# 277632
# Cut wav
# 192000
# 298368
# Cut wav
# 192000
# 223488
# Cut wav
# 192000
# 194688
# Cut wav
# 192000
# 217728
# Cut wav
# 192000
# 223488
# Cut wav
# 192000
# 211968
# Cut wav
# 192000
# 206208
# Cut wav
# 192000
# 309888
# Cut wav
# 192000
# 240768
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 340992
# Cut wav
# 192000
# 275328
# Cut wav
# 192000
# 271872
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 358272
# Cut wav
# 192000
# 260352
# Cut wav
# 192000
# 311040
# Cut wav
# 192000
# 312192
# Cut wav
# 192000
# 162432
# Add zeros
# 192000
# 253440
# Cut wav
# 192000
# 190080
# Add zeros
# 192000
# 201600
# Cut wav
# 192000
# 149760
# Add zeros
# 192000
# 141696
# Add zeros
# 192000
# 133632
# Add zeros
# 192000
# 178560
# Add zeros
# 192000
# 254592
# Cut wav
# 192000
# 178560
# Add zeros
# 192000
# 225792
# Cut wav
# 192000
# 214272
# Cut wav
# 192000
# 135936
# Add zeros
# 192000
# 193536
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 230400
# Cut wav
# 192000
# 168192
# Add zeros
# 192000
# 233856
# Cut wav
# 192000
# 233856
# Cut wav
# 192000
# 191232
# Add zeros
# 192000
# 172800
# Add zeros
# 192000
# 185472
# Add zeros
# 192000
# 172800
# Add zeros
# 192000
# 138240
# Add zeros
# 192000
# 141696
# Add zeros
# 192000
# 191232
# Add zeros
# 192000
# 162432
# Add zeros
# 192000
# 158976
# Add zeros
# 192000
# 144000
# Add zeros
# 192000
# 150912
# Add zeros
# 192000
# 147456
# Add zeros
# 192000
# 213120
# Cut wav
# 192000
# 133632
# Add zeros
# 192000
# 139392
# Add zeros
# 192000
# 247680
# Cut wav
# 192000
# 155520
# Add zeros
# 192000
# 172800
# Add zeros
# 192000
# 277632
# Cut wav
# 192000
# 135936
# Add zeros
# 192000
# 262656
# Cut wav
# 192000
# 170496
# Add zeros
# 192000
# 164736
# Add zeros
# 192000
# 184320
# Add zeros
# 192000
# 132480
# Add zeros
# 192000
# 139392
# Add zeros
# 192000
# 260352
# Cut wav
# 192000
# 184320
# Add zeros
# 192000
# 213120
# Cut wav
# 192000
# 191232
# Add zeros
# 192000
# 173952
# Add zeros
# 192000
# 138240
# Add zeros
# 192000
# 144000
# Add zeros
# 192000
# 432000
# Cut wav
# 192000
# 236160
# Cut wav
# 192000
# 231552
# Cut wav
# 192000
# 201600
# Cut wav
# 192000
# 252288
# Cut wav
# 192000
# 241920
# Cut wav
# 192000
# 307584
# Cut wav
# 192000
# 261504
# Cut wav
# 192000
# 199296
# Cut wav
# 192000
# 194688
# Cut wav
# 192000
# 209664
# Cut wav
# 192000
# 214272
# Cut wav
# 192000
# 210816
# Cut wav
# 192000
# 211968
# Cut wav
# 192000
# 220032
# Cut wav
# 192000
# 224640
# Cut wav
# 192000
# 241920
# Cut wav
# 192000
# 195840
# Cut wav
# 192000
# 223488
# Cut wav
# 192000
# 226944
# Cut wav
# 192000
# 193536
# Cut wav
# 192000
# 198144
# Cut wav
# 192000
# 228096
# Cut wav
# 192000
# 288000
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 195840
# Cut wav
# 192000
# 229248
# Cut wav
# 192000
# 199296
# Cut wav
# 192000
# 229248
# Cut wav
# 192000
# 281088
# Cut wav
# 192000
# 252288
# Cut wav
# 192000
# 231552
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 225792
# Cut wav
# 192000
# 289152
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 317952
# Cut wav
# 192000
# 271872
# Cut wav
# 192000
# 283392
# Cut wav
# 192000
# 338688
# Cut wav
# 192000
# 364032
# Cut wav
# 192000
# 390528
# Cut wav
# 192000
# 317952
# Cut wav
# 192000
# 237312
# Cut wav
# 192000
# 338688
# Cut wav
# 192000
# 281088
# Cut wav
# 192000
# 283392
# Cut wav
# 192000
# 240768
# Cut wav
# 192000
# 289152
# Cut wav
# 192000
# 252288
# Cut wav
# 192000
# 312192
# Cut wav
# 192000
# 379008
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 421632
# Cut wav
# 192000
# 211968
# Cut wav
# 192000
# 433152
# Cut wav
# 192000
# 315648
# Cut wav
# 192000
# 263808
# Cut wav
# 192000
# 260352
# Cut wav
# 192000
# 292608
# Cut wav
# 192000
# 235008
# Cut wav
# 192000
# 252288
# Cut wav
# 192000
# 208512
# Cut wav
# 192000
# 220032
# Cut wav
# 192000
# 237312
# Cut wav
# 192000
# 208512
# Cut wav
# 192000
# 367488
# Cut wav
# 192000
# 225792
# Cut wav
# 192000
# 214272
# Cut wav
# 192000
# 246528
# Cut wav
# 192000
# 237312
# Cut wav
# 192000
# 243072
# Cut wav
# 192000
# 243072
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 208512
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 258048
# Cut wav
# 192000
# 247680
# Cut wav
# 192000
# 300672
# Cut wav
# 192000
# 194688
# Cut wav
# 192000
# 251136
# Cut wav
# 192000
# 210816
# Cut wav
# 192000
# 150912
# Add zeros
# 192000
# 198144
# Cut wav
# 192000
# 175104
# Add zeros
# 192000
# 141696
# Add zeros
# 192000
# 176256
# Add zeros
# 192000
# 208512
# Cut wav
# 192000
# 167040
# Add zeros
# 192000
# 130176
# Add zeros
# 192000
# 216576
# Cut wav
# 192000
# 200448
# Cut wav
# 192000
# 177408
# Add zeros
# 192000
# 216576
# Cut wav
# 192000
# 215424
# Cut wav
# 192000
# 201600
# Cut wav
# 192000
# 164736
# Add zeros
# 192000
# 171648
# Add zeros
# 192000
# 172800
# Add zeros
# 192000
# 188928
# Add zeros
# 192000
# 179712
# Add zeros
# 192000
# 173952
# Add zeros
# 192000
# 206208
# Cut wav
# 192000
# 255744
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 246528
# Cut wav
# 192000
# 156672
# Add zeros
# 192000
# 150912
# Add zeros
# 192000
# 160128
# Add zeros
# 192000
# 260352
# Cut wav
# 192000
# 154368
# Add zeros
# 192000
# 132480
# Add zeros
# 192000
# 186624
# Add zeros
# 192000
# 184320
# Add zeros
# 192000
# 146304
# Add zeros
# 192000
# 200448
# Cut wav
# 192000
# 220032
# Cut wav
# 192000
# 273024
# Cut wav
# 192000
# 200448
# Cut wav
# 192000
# 179712
# Add zeros
# 192000
# 260352
# Cut wav
# 192000
# 195840
# Cut wav
# 192000
# 164736
# Add zeros
# 192000
# 211968
# Cut wav
# 192000
# 208512
# Cut wav
# 192000
# 183168
# Add zeros
# 192000
# 147456
# Add zeros
# 192000
# 180864
# Add zeros
# 192000
# 153216
# Add zeros
# 192000
# 187776
# Add zeros
# 192000
# 130176
# Add zeros
# 192000
# 145152
# Add zeros
# 192000
# 132480
# Add zeros
# 192000
# 188928
# Add zeros
# 192000
# 231552
# Cut wav
# 192000
# 179712
# Add zeros
# 192000
# 256896
# Cut wav
# 192000
# 285696
# Cut wav
# 192000
# 274176
# Cut wav
# 192000
# 201600
# Cut wav
# 192000
# 190080
# Add zeros
# 192000
# 259200
# Cut wav
# 192000
# 210816
# Cut wav
# 192000
# 187776
# Add zeros
# 192000
# 207360
# Cut wav
# 192000
# 176256
# Add zeros
# 192000
# 173952
# Add zeros
# 192000
# 243072
# Cut wav
# 192000
# 259200
# Cut wav
# 192000
# 147456
# Add zeros
# 192000
# 251136
# Cut wav
# 192000
# 199296
# Cut wav
# 192000
# 150912
# Add zeros
# 192000
# 161280
# Add zeros
# 192000
# 195840
# Cut wav
# 192000
# 214272
# Cut wav
# 192000
# 201600
# Cut wav
# 192000
# 239616
# Cut wav
# 192000
# 130176
# Add zeros
# 192000
# 316800
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 173952
# Add zeros
# 192000
# 173952
# Add zeros
# 192000
# 228096
# Cut wav
# 192000
# 168192
# Add zeros
# 192000
# 141696
# Add zeros
# 192000
# 202752
# Cut wav
# 192000
# 172800
# Add zeros
# 192000
# 220032
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 149760
# Add zeros
# 192000
# 172800
# Add zeros
# 192000
# 243072
# Cut wav
# 192000
# 300672
# Cut wav
# 192000
# 201600
# Cut wav
# 192000
# 225792
# Cut wav
# 192000
# 195840
# Cut wav
# 192000
# 205056
# Cut wav
# 192000
# 144000
# Add zeros
# 192000
# 199296
# Cut wav
# 192000
# 206208
# Cut wav
# 192000
#
# Cut wav
# 192000
# 263808
# Cut wav
# 192000
# 175104
# Add zeros
# 192000
# 129024
# Add zeros
# 192000
# 170496
# Add zeros
# 192000
# 152064
# Add zeros
# 192000
# 191232
# Add zeros
# 192000
# 185472
# Add zeros
# 192000
# 213120
# Cut wav
# 192000
# 178560
# Add zeros
# 192000
# 497664
# Cut wav
# 192000
# 293760
# Cut wav
# 192000
# 321408
# Cut wav
# 192000
# 210816
# Cut wav
# 192000
# 233856
# Cut wav
# 192000
# 345600
# Cut wav
# 192000
# 327168
# Cut wav
# 192000
# 298368
# Cut wav
# 192000
# 211968
# Cut wav
# 192000
# 214272
# Cut wav
# 192000
# 262656
# Cut wav
# 192000
# 235008
# Cut wav
# 192000
# 306432
# Cut wav
# 192000
# 308736
# Cut wav
# 192000
# 241920
# Cut wav
# 192000
# 238464
# Cut wav
# 192000
# 231552
# Cut wav
# 192000
# 261504
# Cut wav
# 192000
# 267264
# Cut wav
# 192000
# 198144
# Cut wav
# 192000
# 225792
# Cut wav
# 192000
# 214272
# Cut wav
# 192000
# 285696
# Cut wav
# 192000
# 218880
# Cut wav
# 192000
# 237312
# Cut wav
# 192000
# 205056
# Cut wav
# 192000
# 223488
# Cut wav
# 192000
# 263808
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 285696
# Cut wav
# 192000
# 352512
# Cut wav
# 192000
# 193536
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 228096
# Cut wav
# 192000
# 195840
# Cut wav
# 192000
# 330624
# Cut wav
# 192000
# 223488
# Cut wav
# 192000
# 210816
# Cut wav
# 192000
# 208512
# Cut wav
# 192000
# 216576
# Cut wav
# 192000
# 237312
# Cut wav
# 192000
# 208512
# Cut wav
# 192000
# 207360
# Cut wav
# 192000
# 203904
# Cut wav
# 192000
# 198144
# Cut wav
# 192000
# 215424
# Cut wav
# 192000
# 255744
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 247680
# Cut wav
# 192000
# 210816
# Cut wav
# 192000
# 223488
# Cut wav
# 192000
# 258048
# Cut wav
# 192000
# 261504
# Cut wav
# 192000
# 210816
# Cut wav
# 192000
# 326016
# Cut wav
# 192000
# 323712
# Cut wav
# 192000
# 209664
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 206208
# Cut wav
# 192000
# 256896
# Cut wav
# 192000
# 215424
# Cut wav
# 192000
# 261504
# Cut wav
# 192000
# 267264
# Cut wav
# 192000
# 330624
# Cut wav
# 192000
# 273024
# Cut wav
# 192000
# 273024
# Cut wav
# 192000
# 335232
# Cut wav
# 192000
# 330624
# Cut wav
# 192000
# 304128
# Cut wav
# 192000
# 195840
# Cut wav
# 192000
# 132480
# Add zeros
# 192000
# 216576
# Cut wav
# 192000
# 144000
# Add zeros
# 192000
# 213120
# Cut wav
# 192000
# 231552
# Cut wav
# 192000
# 139392
# Add zeros
# 192000
# 251136
# Cut wav
# 192000
# 256896
# Cut wav
# 192000
# 191232
# Add zeros
# 192000
# 208512
# Cut wav
# 192000
# 168192
# Add zeros
# 192000
# 168192
# Add zeros
# 192000
# 236160
# Cut wav
# 192000
# 132480
# Add zeros
# 192000
# 173952
# Add zeros
# 192000
# 150912
# Add zeros
# 192000
# 178560
# Add zeros
# 192000
# 216576
# Cut wav
# 192000
# 251136
# Cut wav
# 192000
# 187776
# Add zeros
# 192000
# 190080
# Add zeros
# 192000
# 187776
# Add zeros
# 192000
# 139392
# Add zeros
# 192000
# 170496
# Add zeros
# 192000
# 241920
# Cut wav
# 192000
# 138240
# Add zeros
# 192000
# 201600
# Cut wav
# 192000
# 190080
# Add zeros
# 192000
# 289152
# Cut wav
# 192000
# 144000
# Add zeros
# 192000
# 195840
# Cut wav
# 192000
# 182016
# Add zeros
# 192000
# 168192
# Add zeros
# 192000
# 199296
# Cut wav
# 192000
# 139392
# Add zeros
# 192000
# 266112
# Cut wav
# 192000
# 150912
# Add zeros
# 192000
# 178560
# Add zeros
# 192000
# 139392
# Add zeros
# 192000
# 153216
# Add zeros
# 192000
# 216576
# Cut wav
# 192000
# 172800
# Add zeros
# 192000
# 145152
# Add zeros
# 192000
# 135936
# Add zeros
# 192000
# 139392
# Add zeros
# 192000
# 167040
# Add zeros
# 192000
# 236160
# Cut wav
# 192000
# 147456
# Add zeros
# 192000
# 135936
# Add zeros
# 192000
# 231552
# Cut wav
# 192000
# 133632
# Add zeros
# 192000
# 141696
# Add zeros
# 192000
# 182016
# Add zeros
# 192000
# 167040
# Add zeros
# 192000
# 195840
# Cut wav
# 192000
# Cut wav
# 192000
# 258048
# Cut wav
# 192000
# 260352
# Cut wav
# 192000
# 258048
# Cut wav
# 192000
# 355968
# Cut wav
# 192000
# 312192
# Cut wav
# 192000
# 194688
# Cut wav
# 192000
# 229248
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 286848
# Cut wav
# 192000
# 220032
# Cut wav
# 192000
# 220032
# Cut wav
# 192000
# 218880
# Cut wav
# 192000
# 133632
# Add zeros
# 192000
# 155520
# Add zeros
# 192000
# 185472
# Add zeros
# 192000
# 190080
# Add zeros
# 192000
# 237312
# Cut wav
# 192000
# 132480
# Add zeros
# 192000
# 247680
# Cut wav
# 192000
# 179712
# Add zeros
# 192000
# 199296
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 195840
# Cut wav
# 192000
# 216576
# Cut wav
# 192000
# 225792
# Cut wav
# 192000
# 132480
# Add zeros
# 192000
# 132480
# Add zeros
# 192000
# 254592
# Cut wav
# 192000
# 266112
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 231552
# Cut wav
# 192000
# 300672
# Cut wav
# 192000
# 229248
# Cut wav
# 192000
# 263808
# Cut wav
# 192000
# 223488
# Cut wav
# 192000
# 217728
# Cut wav
# 192000
# 309888
# Cut wav
# 192000
# 217728
# Cut wav
# 192000
# 237312
# Cut wav
# 192000
# 289152
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 258048
# Cut wav
# 192000
# 243072
# Cut wav
# 192000
# 298368
# Cut wav
# 192000
# 248832
# Cut wav
# 192000
# 217728
# Cut wav
# 192000
# 286848
# Cut wav
# 192000
# 203904
# Cut wav
# 192000
# 213120
# Cut wav
# 192000
# 163584
# Add zeros
# 192000
# 206208
# Cut wav
# 192000
# 229248
# Cut wav
# 192000
# 177408
# Add zeros
# 192000
# 134784
# Add zeros
# 192000
# 292608
# Cut wav
# 192000
# 238464
# Cut wav
# 192000
# 246528
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 203904
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 178560
# Add zeros
# 192000
# 188928
# Add zeros
# 192000
# 214272
# Cut wav
# 192000
# 208512
# Cut wav
# 192000
# 191232
# Add zeros
# 192000
# 217728
# Cut wav
# 192000
# 139392
# Add zeros
# 192000
# 132480
# Add zeros
# 192000
# 141696
# Add zeros
# 192000
# 154368
# Add zeros
# 192000
# 131328
# Add zeros
# 192000
# 133632
# Add zeros
# 192000
# 261504
# Cut wav
# 192000
# 205056
# Cut wav
# 192000
# 156672
# Add zeros
# 192000
# 201600
# Cut wav
# 192000
# 154368
# Add zeros
# 192000
# 225792
# Cut wav
# 192000
# 145152
# Add zeros
# 192000
# 145152
# Add zeros
# 192000
# 191232
# Add zeros
# 192000
# 130176
# Add zeros
# 192000
# 139392
# Add zeros
# 192000
# 184320
# Add zeros
# 192000
# 211968
# Cut wav
# 192000
# 195840
# Cut wav
# 192000
# 146304
# Add zeros
# 192000
# 173952
# Add zeros
# 192000
# 173952
# Add zeros
# 192000
# 153216
# Add zeros
# 192000
# 135936
# Add zeros
# 192000
# 148608
# Add zeros
# 192000
# 203904
# Cut wav
# 192000
# 177408
# Add zeros
# 192000
# 147456
# Add zeros
# 192000
# 251136
# Cut wav
# 192000
# 129024
# Add zeros
# 192000
# 146304
# Add zeros
# 192000
# 168192
# Add zeros
# 192000
# 194688
# Cut wav
# 192000
# 154368
# Add zeros
# 192000
# 163584
# Add zeros
# 192000
# 163584
# Add zeros
# 192000
# 157824
# Add zeros
# 192000
# 163584
# Add zeros
# 192000
# 240768
# Cut wav
# 192000
# 156672
# Add zeros
# 192000
# 147456
# Add zeros
# 192000
# 141696
# Add zeros
# 192000
# 188928
# Add zeros
# 192000
# 162432
# Add zeros
# 192000
# 214272
# Cut wav
# 192000
# 304128
# Cut wav
# 192000
# 194688
# Cut wav
# 192000
# 350208
# Cut wav
# 192000
# 235008
# Cut wav
# 192000
# 369792
# Cut wav
# 192000
# 266112
# Cut wav
# 192000
# 312192
# Cut wav
# 192000
# 220032
# Cut wav
# 192000
# 243072
# Cut wav
# 192000
# 358272
# Cut wav
# 192000
# 263808
# Cut wav
# 192000
# 231552
# Cut wav
# 192000
# 309888
# Cut wav
# 192000
# 225792
# Cut wav
# 192000
# 384768
# Cut wav
# 192000
# 266112
# Cut wav
# 192000
# 335232
# Cut wav
# 192000
# 196992
# Cut wav
# 192000
# 254592
# Cut wav
# 192000
# 202752
# Cut wav
# 192000
# 208512
# Cut wav
# 192000
# 263808
# Cut wav
# 192000
# 286848
# Cut wav
# pandas.core.series.Series

# %%
test_align_tensors.to_list()
# Out:
# [<tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.00595093,  0.0017395 ,  0.00494385, ...,  0.00085449,
#         -0.00119019, -0.00213623], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.00177002,  0.00253296, -0.00018311, ..., -0.00228882,
#         -0.00177002,  0.00228882], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.0067749 , -0.01849365, -0.03494263, ..., -0.00558472,
#         -0.00332642, -0.00396729], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.00585938,  0.00231934,  0.00497437, ..., -0.00045776,
#          0.00683594,  0.00695801], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.00726318,  0.01089478,  0.0100708 , ...,  0.00073242,
#          0.00106812, -0.00039673], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 1.7669678e-02, -9.0332031e-03, -1.5502930e-02, ...,
#          9.1552734e-05,  0.0000000e+00,  4.5776367e-04], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.10412598, -0.11480713, -0.12316895, ...,  0.05010986,
#          0.04244995,  0.03829956], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([8.2397461e-04, 6.7138672e-04, 3.9672852e-04, ..., 6.1035156e-05,
#         2.4414062e-04, 6.1035156e-04], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.00109863,  0.0010376 ,  0.00076294, ...,  0.00109863,
#          0.00073242, -0.00057983], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-2.7465820e-03, -2.8076172e-03,  5.1879883e-04, ...,
#          6.1035156e-05,  3.0517578e-04, -6.1035156e-05], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.00204468,  0.00076294, -0.00021362, ...,  0.00036621,
#         -0.00015259,  0.00030518], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 9.1552734e-05, -1.8310547e-04,  1.8310547e-04, ...,
#          4.8522949e-03, -2.9296875e-03,  2.7130127e-02], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.00161743,  0.00146484,  0.00128174, ..., -0.01248169,
#         -0.01248169, -0.0123291 ], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.07739258, -0.00979614,  0.05581665, ...,  0.01855469,
#          0.01889038,  0.0189209 ], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([0.4050293 , 0.43301392, 0.44857788, ..., 0.0725708 , 0.05410767,
#         0.01702881], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.00701904, -0.00411987, -0.00048828, ...,  0.19793701,
#          0.20220947,  0.19882202], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-3.0517578e-05, -1.5258789e-04, -3.0517578e-04, ...,
#          5.6457520e-03,  1.4404297e-02,  1.9531250e-02], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.00061035, -0.01580811, -0.02890015, ..., -0.0128479 ,
#         -0.01864624, -0.02420044], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.        ,  0.        ,  0.        , ..., -0.32247925,
#         -0.32037354, -0.3142395 ], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.01086426, -0.00393677,  0.00326538, ...,  0.        ,
#          0.        ,  0.        ], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 6.1035156e-05, -4.8828125e-04, -8.5449219e-04, ...,
#         -6.1035156e-05, -6.1035156e-05, -3.0517578e-05], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.06066895, -0.07104492, -0.07730103, ..., -0.1463623 ,
#         -0.14300537, -0.1390686 ], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.00213623, -0.00149536,  0.00012207, ...,  0.        ,
#          0.        ,  0.        ], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.03833008,  0.03872681,  0.03970337, ..., -0.11221313,
#         -0.11560059, -0.11907959], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([0.06716919, 0.08517456, 0.10192871, ..., 0.12197876, 0.11599731,
#         0.10232544], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-3.0517578e-05,  6.1035156e-05,  9.1552734e-05, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.
dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-1.2207031e-04, -1.5258789e-04, -1.5258789e-04, ...,
#          1.2207031e-04,  9.1552734e-05,  3.0517578e-05], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.02923584, -0.03860474, -0.04730225, ...,  0.0619812 ,
#          0.06411743,  0.06600952], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-6.1035156e-05, -9.1552734e-05, -6.1035156e-05, ...,
#         -9.1552734e-05, -9.1552734e-05, -9.1552734e-05], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.00189209, -0.00045776,  0.00222778, ...,  0.02157593,
#          0.02377319,  0.02575684], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-9.1552734e-05, -9.1552734e-05, -1.2207031e-04, ...,
#         -1.2207031e-04, -1.5258789e-04, -1.5258789e-04], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-7.3242188e-04, -7.3242188e-04, -7.0190430e-04, ...,
#          3.3569336e-04,  2.4414062e-04,  6.1035156e-05], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([1.2207031e-04, 9.1552734e-05, 6.1035156e-05, ..., 3.0517578e-05,
#         6.1035156e-05, 9.1552734e-05], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.00024414, -0.00024414, -0.00021362, ...,  0.00024414,
#          0.00021362,  0.00018311], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.0000000e+00, -3.0517578e-05, -3.0517578e-05, ...,
#          6.6528320e-03,  6.7749023e-03,  6.8969727e-03], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-1.5258789e-04, -1.5258789e-04, -1.5258789e-04, ...,
#         -1.6607666e-01, -1.6369629e-01, -1.5750122e-01], dtype=float32)>]

# %%
train_align_dataset = tf.data.Dataset.from_tensor_slices(train_align_tensors.to_list())
test_align_dataset = tf.data.Dataset.from_tensor_slices(val_align_tensors.to_list())
val_align_dataset = tf.data.Dataset.from_tensor_slices(test_align_tensors.to_list())

test_align_dataset
# Out:
# <_TensorSliceDataset element_spec=TensorSpec(shape=(192000,), dtype=tf.float32, name=None)>

# %%
# test_align_dataset.as_numpy_iterator().next()

# %%
# pl_dataset_test.as_numpy_iterator().next()

# %%
# clip = load_wav_16k_mono_and_resample(df_train_filenames[0])
# print(clip)

# %%
# plt.plot(clip)

# %%
# cut_clip = cut_wav(clip, sample_rate)
# cut_clip

# %%
# add_zeros(wav[:30000], sample_rate)

# %%
# def align_probes(wav, sample_rate):
#     # wav = load_wav_16k_mono_and_resample(file_path)
#     expected_probes = int((MIN_CLIP_DURATION/1000) * sample_rate)
#     print(expected_probes)
#     current_probes = wav.shape[0]
#     print(current_probes)
#     if expected_probes > current_probes:
#         print("Add zeros")
#         wav = add_zeros(wav, sample_rate)
#     elif expected_probes < current_probes:
#         print("Cut wav")
#         wav = cut_wav(wav, sample_rate)
#     return wav

# %%
def align_probes(wav, sample_rate):
    # wav = load_wav_16k_mono_and_resample(file_path)
    expected_probes = (MIN_CLIP_DURATION/1000) * sample_rate
    print(expected_probes)
    current_probes = wav.shape[0]
    print(current_probes)
    if expected_probes > current_probes:
        print("Add zeros")
        return add_zeros(wav, sample_rate)
    if expected_probes < current_probes:
        print("Cut wav")
        return cut_wav(wav, sample_rate)
    return wav

# %%
# a = align_probes(cut_clip, sample_rate)
# a

# %%
# plt.plot(a)

# %%
MIN_CLIP_DURATION/1000* sample_rate
# Out:
# 192000.0

# %%
def increase_amplitude(wav, min_increase=2.0, max_increase=5.0):
    increased_wav = wav * random.uniform(min_increase, max_increase)
    return tf.convert_to_tensor(increased_wav, dtype=tf.float32)

# %%
# inc_a = increase_amplitude(a)

# %%
# plt.plot(inc_a)

# %%
def normalize_audio(wav):
    max_amplitude = tf.reduce_max(tf.abs(wav))
    normalized_wav = wav / max_amplitude  # Normalizacja do zakresu [-1, 1]
    return normalized_wav

# %%
# norm_a = normalize_audio(inc_a)
# norm_a

# %%
# plt.plot(norm_a)

# %%
def add_noise(wav, noise_level=0.1):
    noise = tf.random.normal(tf.shape(wav), mean=0.0, stddev=noise_level)
    return wav + noise

# %%
# noise_a = add_noise(inc_a)
# noise_a

# %%
# plt.plot(noise_a)

# %%
def time_masking(wav, max_mask_length=10000):
    # Sprawdzenie długości wav
        # Sprawdzenie czy wav jest pusty lub ma nieprawidłowy kształt
    if wav is None or tf.rank(wav) != 1:
        return wav
    
    # Sprawdzenie długości wav
    if tf.shape(wav)[0] <= max_mask_length:
        return wav
    
    # Losowa długość maskowania
    mask_length = tf.random.uniform([], maxval=max_mask_length, dtype=tf.int32)
    
    # Sprawdzenie, czy maska nie wyjdzie poza zakres
    mask_start_max = tf.shape(wav)[0] - mask_length
    mask_start = tf.random.uniform([], maxval=mask_start_max, dtype=tf.int32)
    
    # Stworzenie maski czasowej
    mask = tf.concat([
        tf.ones([mask_start]),
        tf.zeros([mask_length]),
        tf.ones([tf.shape(wav)[0] - mask_start - mask_length])
    ], axis=0)
    
    # Zastosowanie maskowania do sygnału audio
    masked_wav = wav * mask
    
    return masked_wav

# %%
# masked_a = time_masking(inc_a, max_mask_length=50000)
# masked_a

# %%
# plt.plot(masked_a)

# %%
def change_pitch(wav, sample_rate=48000, pitch_shift=2):
    wav_np = wav.numpy()  # Convert tensor to numpy array
    pitched_wav = librosa.effects.pitch_shift(wav_np, sr=sample_rate, n_steps=pitch_shift)
    return tf.convert_to_tensor(pitched_wav, dtype=tf.float32)

# %%
# pitch_a = change_pitch(inc_a, sample_rate)
# pitch_a

# %%
# plt.plot(pitch_a)

# %%
def speed_up_audio(wav, speed_factor=2):
    # Pobierz tablicę numpy z tensora Tensorflow
    wav_np = wav.numpy()
    
    # Zastosuj przyspieszenie do danych audio
    stretched_wav = librosa.effects.time_stretch(wav_np, rate=speed_factor)
    
    return stretched_wav

# %%
# speed_a = speed_up_audio(inc_a)
# speed_a

# %%
# plt.plot(speed_a)

# %%
def slow_down_audio(wav, speed_factor=0.5):
    # Konwertujemy tensor na tablicę numpy
    wav_np = wav.numpy()
    
    # Przeprowadzamy zwolnienie tempa za pomocą librosa
    slowed_wav_np = librosa.effects.time_stretch(wav_np, rate=speed_factor)
    
    # Konwertujemy wynikową tablicę numpy z powrotem na tensor TensorFlow
    return tf.convert_to_tensor(slowed_wav_np, dtype=tf.float32)

# %%
# slow_a = slow_down_audio(wav)

# %%
# plt.plot(slow_a)

# %%
audio_processing_functions = [increase_amplitude, add_noise, time_masking, change_pitch]
def process_random_samples(dataset, num_samples_to_process):
    processed_samples = []
    for _ in range(num_samples_to_process):
        shuffled_dataset = dataset.shuffle(buffer_size=1000)
        random_sample =  next(iter(shuffled_dataset.take(1)))

        # Dobycie tensora z datasetu
  # Tutaj uzyskujemy tensor danych audio

        processing_function = random.choice(audio_processing_functions)
        processed_sample = processing_function(random_sample)

        processed_samples.append(processed_sample)

    return processed_samples

# %%
# Wczytaj, przetwórz i zapisz przetworzone pliki audio z pl_dataset_train
# pl_dataset_train_processed = pl_dataset_train.map(lambda filename: load_wav_16k_mono_and_resample(filename))
# pl_dataset_val_processed = pl_dataset_val.map(lambda filename:load_wav_16k_mono_and_resample(filename))
# pl_dataset_test_processed = pl_dataset_test.map(lambda filename: load_wav_16k_mono_and_resample(filename))
# 
# pl_dataset_train_processed.as_numpy_iterator().next().shape[0]

# %%
processed_samples_train = process_random_samples(train_align_dataset, TRAIN_SIZE - len(train_align_dataset))
processed_samples_val = process_random_samples(val_align_dataset, (VAL_SIZE - len(val_align_dataset)))
processed_samples_test = process_random_samples(test_align_dataset, (TEST_SIZE - len(test_align_dataset)))
# processed_samples_test

# %%
align_processed_train = [align_probes(tensor, sample_rate) for tensor in processed_samples_train]
align_processed_val = [align_probes(tensor, sample_rate) for tensor in processed_samples_val]
align_processed_test = [align_probes(tensor,sample_rate) for tensor in processed_samples_test]
align_processed_train
# Out:
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# 192000.0
# 192000
# [<tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.07878111, -0.07628694, -0.11983574, ..., -0.04228945,
#         -0.14864366,  0.00489518], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([ 0.01247546,  0.06550079, -0.04508541, ..., -0.18464199,
#          0.08517962, -0.01539981], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([0.00079346, 0.00085449, 0.00076294, ..., 0.00015259, 0.00039673,
#         0.00057983], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-3.9874221e-04, -7.4399961e-04, -8.2312821e-04, ...,
#          9.9549128e-05,  8.5311054e-05,  1.3806313e-04], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([0.00026363, 0.00039544, 0.00079088, ..., 0.00026363, 0.00052725,
#         0.00013181], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=
#  array([-0.6277447 , -0.6265474 , -0.5688936 , ...,  0.2621129 ,
#          0.2190107 ,  0.17305344], dtype=float32)>,
#  <tf.Tensor: shape=(192000,), dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>]

# %%
processed_samples_train_dataset = tf.data.Dataset.from_tensor_slices(align_processed_train)
processed_samples_val_dataset = tf.data.Dataset.from_tensor_slices(align_processed_val)
processed_samples_test_dataset = tf.data.Dataset.from_tensor_slices(align_processed_test)

# %%
processed_samples_test_dataset.as_numpy_iterator()
# Out:
# NumpyIterator(iterator=<tensorflow.python.data.ops.iterator_ops.OwnedIterator object at 0x00000217D6CA2620>)

# %%
# align_pl_dataset_train_with_processed_samples = pl_dataset_train_processed.map(lambda audio: align_probes(audio, sample_rate))
# align_pl_dataset_val_with_processed_samples = pl_dataset_val_processed.map(lambda audio: align_probes(audio, sample_rate))
# align_pl_dataset_test_with_processed_samples = pl_dataset_test_processed.map(lambda audio: align_probes(audio, sample_rate))
train_dataset_con = train_align_dataset.concatenate(processed_samples_train_dataset)
val_dataset_con = val_align_dataset.concatenate(processed_samples_val_dataset)
test_dataset_con = test_align_dataset.concatenate(processed_samples_test_dataset)

# %%
align_pl_dataset_train_with_processed_samples_norm = train_dataset_con.map(lambda audio: normalize_audio(audio))
align_pl_dataset_val_with_processed_samples_norm = val_dataset_con.map(lambda audio: normalize_audio(audio))
align_pl_dataset_test_with_processed_samples_norm = test_dataset_con.map(lambda audio: normalize_audio(audio))

# %%
def create_spectrogram(wav):
    spectrogram = tf.signal.stft(wav, frame_length=320, frame_step=32)
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.expand_dims(spectrogram, axis=2)
    return spectrogram

# %%
spectrogram = create_spectrogram(wav_example)

print(spectrogram.shape)
spectrogram = tf.squeeze(spectrogram, axis=-1)
print(spectrogram.shape)
# spectrogram_in_db = 20 * tf.math.log(spectrogram + 1e-10) / tf.math.log(10.0)
plt.figure(figsize=(10, 4))
plt.imshow(tf.transpose(spectrogram), aspect='auto', origin='lower', cmap='viridis', extent=[0, 10, 0, sample_rate / 2])
plt.colorbar(label='Magnitude')
plt.xlabel('Time [s]')
plt.ylabel('Frequency [Hz]')
plt.title('Spectrogram')
plt.show()

# (2499, 257, 1) 2499 - liczba ramek czasowych, 257 - punkty częstotliwościowe dla danej ramki (każdej) + 1 na f = 0, 1 - jednokanalość danych
# Out:
# (2499, 257, 1)
# (2499, 257)

# %%
# spectrogram = create_spectrogram(pitch_a)
# print(spectrogram.shape)
# 
# spectrogram = tf.squeeze(spectrogram, axis=-1)
# print(spectrogram.shape)
# plt.figure(figsize=(10, 4))
# plt.imshow(tf.transpose(spectrogram), aspect='auto', origin='lower', cmap='viridis', extent=[0, 10, 0, sample_rate / 2])
# plt.colorbar(label='Magnitude')
# plt.xlabel('Time [s]')
# plt.ylabel('Frequency [Hz]')
# plt.title('Spectrogram')
# plt.show()

# %%
spectrogram_pl_dataset_train = align_pl_dataset_train_with_processed_samples_norm.map(lambda audio: create_spectrogram(audio))
spectrogram_pl_dataset_val = align_pl_dataset_val_with_processed_samples_norm.map(lambda audio: create_spectrogram(audio))
spectrogram_pl_dataset_test = align_pl_dataset_test_with_processed_samples_norm.map(lambda audio: create_spectrogram(audio))

# %%
spectrogram_pl_dataset_train
# Out:
# <_MapDataset element_spec=TensorSpec(shape=(5991, 257, 1), dtype=tf.float32, name=None)>

# %%
spectrogram_pl_dataset_val
# Out:
# <_MapDataset element_spec=TensorSpec(shape=(5991, 257, 1), dtype=tf.float32, name=None)>

# %%
spectrogram_pl_dataset_test
# Out:
# <_MapDataset element_spec=TensorSpec(shape=<unknown>, dtype=tf.float32, name=None)>

# %%
spectrogram_pl_dataset_test.as_numpy_iterator().next().shape
# Out:
# (5991, 257, 1)

# %%
labeled_train_dataset = tf.data.Dataset.zip((spectrogram_pl_dataset_train, tf.data.Dataset.from_tensor_slices(tf.ones(len(spectrogram_pl_dataset_train)))))
labeled_val_dataset = tf.data.Dataset.zip((spectrogram_pl_dataset_val, tf.data.Dataset.from_tensor_slices(tf.ones(len(spectrogram_pl_dataset_val)))))
labeled_test_dataset = tf.data.Dataset.zip((spectrogram_pl_dataset_test, tf.data.Dataset.from_tensor_slices(tf.ones(len(spectrogram_pl_dataset_test)))))

# %%
labeled_train_dataset.as_numpy_iterator().next()
# Out:
# (array([[[1.6102961e-01],
#          [1.3767413e+00],
#          [1.6972234e+00],
#          ...,
#          [2.5779635e-03],
#          [2.3084767e-03],
#          [1.7871484e-03]],
#
#         [[3.9687282e-01],
#          [1.0791707e+00],
#          [1.7546517e+00],
#          ...,
#          [2.0486037e-03],
#          [1.7593920e-03],
#          [3.8044155e-04]],
#
#         [[4.2090124e-01],
#          [1.0430394e+00],
#          [1.9488876e+00],
#          ...,
#          [1.5188577e-03],
#          [1.5761391e-03],
#          [8.6587667e-04]],
#
#         ...,
#
#         [[2.1391127e-01],
#          [4.1440710e-01],
#          [4.9005103e-01],
#          ...,
#          [7.3411393e-05],
#          [2.5087674e-04],
#          [1.9795448e-04]],
#
#         [[8.5746996e-02],
#          [2.5741404e-01],
#          [3.0369604e-01],
#          ...,
#          [2.7098754e-04],
#          [1.4798039e-04],
#          [3.0256808e-05]],
#
#         [[2.1340014e-01],
#          [2.3037885e-01],
#          [2.0047496e-01],
#          ...,
#          [3.5209089e-04],
#          [1.2599188e-04],
#          [9.8034739e-05]]], dtype=float32),
#  1.0)

# %%
labeled_val_dataset.as_numpy_iterator().next()
# Out:
# (array([[[1.37876749e-01],
#          [2.00402346e-02],
#          [6.80927634e-01],
#          ...,
#          [6.67214554e-05],
#          [7.14244961e-05],
#          [5.50746918e-05]],
#
#         [[2.46918909e-02],
#          [1.20690957e-01],
#          [7.29144096e-01],
#          ...,
#          [3.66824825e-05],
#          [3.55997945e-05],
#          [7.48410821e-06]],
#
#         [[4.61639091e-02],
#          [1.72154486e-01],
#          [7.42328465e-01],
#          ...,
#          [2.07657831e-05],
#          [2.58055370e-05],
#          [2.23368406e-05]],
#
#         ...,
#
#         [[8.24453658e-04],
#          [7.39304721e-02],
#          [9.54088345e-02],
#          ...,
#          [1.35245398e-04],
#          [2.26509990e-04],
#          [2.58266111e-04]],
#
#         [[4.80341054e-02],
#          [7.98390433e-02],
#          [1.08579271e-01],
#          ...,
#          [1.39685289e-04],
#          [1.89521859e-04],
#          [2.07569450e-04]],
#
#         [[7.41686076e-02],
#          [8.77853036e-02],
#          [1.09632105e-01],
#          ...,
#          [1.23388410e-04],
#          [1.29332693e-04],
#          [1.53604895e-04]]], dtype=float32),
#  1.0)

# %%
labeled_test_dataset.as_numpy_iterator().next()
# Out:
# (array([[[3.74013209e+00],
#          [5.39764023e+00],
#          [7.43858767e+00],
#          ...,
#          [1.45675120e-04],
#          [1.52246183e-04],
#          [9.08374786e-05]],
#
#         [[1.64014459e+00],
#          [5.23130941e+00],
#          [8.40193558e+00],
#          ...,
#          [1.85948913e-04],
#          [1.81830284e-04],
#          [1.74582005e-04]],
#
#         [[1.28266299e+00],
#          [5.08394098e+00],
#          [8.63815594e+00],
#          ...,
#          [1.30503249e-04],
#          [2.20755741e-04],
#          [2.80737877e-04]],
#
#         ...,
#
#         [[2.83574928e-02],
#          [2.86699403e-02],
#          [2.79197227e-02],
#          ...,
#          [3.62112361e-04],
#          [4.49973915e-04],
#          [5.03895804e-04]],
#
#         [[2.96067558e-02],
#          [2.59775613e-02],
#          [2.21861526e-02],
#          ...,
#          [4.18557058e-04],
#          [5.62685076e-04],
#          [6.26758672e-04]],
#
#         [[2.74669454e-02],
#          [1.94717217e-02],
#          [1.16810845e-02],
#          ...,
#          [4.15729504e-04],
#          [5.98302577e-04],
#          [6.68332912e-04]]], dtype=float32),
#  1.0)
